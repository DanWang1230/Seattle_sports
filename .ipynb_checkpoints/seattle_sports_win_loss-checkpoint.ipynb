# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# %matplotlib notebook

# %% [markdown]
# ## Scrape datasets from wikipedia

# %%
# Seattle Seahawks
url = 'https://en.wikipedia.org/wiki/List_of_Seattle_Seahawks_seasons'

r = requests.get(url)
html = r.text

soup = BeautifulSoup(html, 'html.parser')
table = soup.find_all('table', {"class": "wikitable"})

# %%
# Seattle Mariners
url = 'https://en.wikipedia.org/wiki/List_of_Seattle_Mariners_seasons'

r = requests.get(url)
html = r.text

soup = BeautifulSoup(html, 'html.parser')
table_m = soup.find_all('table', {"class": "wikitable"})

# %%
# Seattle Sounders FC
url = 'https://en.wikipedia.org/wiki/List_of_Seattle_Sounders_FC_seasons'

r = requests.get(url)
html = r.text

soup = BeautifulSoup(html, 'html.parser')
table_s = soup.find_all('table', {"class": "wikitable"})

# %%
table_s
# Out:
# [<table class="wikitable" style="text-align:center">
#  <tbody><tr>
#  <td style="background:gold">1st <small>or</small> W</td>
#  <td>Winners
#  </td></tr>
#  <tr>
#  <td style="background:silver">2nd <small>or</small> RU</td>
#  <td>Runners-up
#  </td></tr>
#  <tr>
#  <td style="background:#CFAA88">3rd
#  </td>
#  <td>Third place
#  </td></tr>
#  <tr>
#  <td style="background:#FFCCCC">Last</td>
#  <td>Last place
#  </td></tr>
#  <tr>
#  <td style='background:#FAECC8;"'>♦</td>
#  <td>League top scorer
#  </td></tr>
#  <tr>
#  <td style="background:#dfd;"> </td>
#  <td>Highest average attendance
#  </td></tr>
#  <tr>
#  <td><i>Italics</i></td>
#  <td>Ongoing competition
#  </td></tr></tbody></table>,
#  <table border="2" cellpadding="4" class="wikitable" style="font-size:90%; text-align:center;" width="100%">
#  <tbody><tr style="background:#f0f6ff;">
#  <th rowspan="2">Season
#  </th>
#  <th colspan="11">League
#  </th>
#  <th colspan="2">Position
#  </th>
#  <th rowspan="2">Playoffs
#  </th>
#  <th rowspan="2"><a href="/wiki/U.S._Open_Cup" title="U.S. Open Cup">USOC</a>
#  </th>
#  <th colspan="2" rowspan="2"><a href="/wiki/CONCACAF" title="CONCACAF">Continental</a> / Other
#  </th>
#  <th rowspan="2"><a href="/wiki/Major_League_Soccer_attendance" title="Major League Soccer attendance">Average <br/> attendance</a>
#  </th>
#  <th colspan="2">Top goalscorer(s)
#  </th></tr>
#  <tr>
#  <th>Div
#  </th>
#  <th>League
#  </th>
#  <th>Pld
#  </th>
#  <th>W
#  </th>
#  <th>L
#  </th>
#  <th>D
#  </th>
#  <th>GF
#  </th>
#  <th>GA
#  </th>
#  <th>GD
#  </th>
#  <th>Pts
#  </th>
#  <th>PPG
#  </th>
#  <th>Conf.
#  </th>
#  <th>Overall
#  </th>
#  <th>Name(s)
#  </th>
#  <th>Goals
#  </th></tr>
#  <tr>
#  <td><b><a href="/wiki/2009_Seattle_Sounders_FC_season" title="2009 Seattle Sounders FC season">2009</a></b>
#  </td>
#  <td rowspan="12">1
#  </td>
#  <td><a href="/wiki/2009_Major_League_Soccer_season" title="2009 Major League Soccer season">MLS</a>
#  </td>
#  <td>30
#  </td>
#  <td>12
#  </td>
#  <td>7
#  </td>
#  <td>11
#  </td>
#  <td>38
#  </td>
#  <td>29
#  </td>
#  <td>+9
#  </td>
#  <td>47
#  </td>
#  <td>1.57
#  </td>
#  <td bgcolor="CFAA88">3rd
#  </td>
#  <td>4th
#  </td>
#  <td><a href="/wiki/2009_MLS_Cup_Playoffs" title="2009 MLS Cup Playoffs">QF</a>
#  </td>
#  <td bgcolor="gold"><a href="/wiki/2009_U.S._Open_Cup_Final" title="2009 U.S. Open Cup Final">W</a>
#  </td>
#  <td colspan="2">DNQ
#  </td>
#  <td>30,943
#  </td>
#  <td align="left"><span class="flagicon"><a href="/wiki/Colombia" title="Colombia"><img alt="Colombia" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/23px-Flag_of_Colombia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/35px-Flag_of_Colombia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/45px-Flag_of_Colombia.svg.png 2x" width="23"/></a></span> <a href="/wiki/Fredy_Montero" title="Fredy Montero">Fredy Montero</a>
#  </td>
#  <td>13
#  </td></tr>
#  <tr>
#  <td><b><a href="/wiki/2010_Seattle_Sounders_FC_season" title="2010 Seattle Sounders FC season">2010</a></b>
#  </td>
#  <td><a href="/wiki/2010_Major_League_Soccer_season" title="2010 Major League Soccer season">MLS</a>
#  </td>
#  <td>30
#  </td>
#  <td>14
#  </td>
#  <td>10
#  </td>
#  <td>6
#  </td>
#  <td>39
#  </td>
#  <td>35
#  </td>
#  <td>+4
#  </td>
#  <td>48
#  </td>
#  <td>1.60
#  </td>
#  <td>4th
#  </td>
#  <td>6th
#  </td>
#  <td><a href="/wiki/2010_MLS_Cup_Playoffs" title="2010 MLS Cup Playoffs">QF</a>
#  </td>
#  <td bgcolor="gold"><a href="/wiki/2010_U.S._Open_Cup_Final" title="2010 U.S. Open Cup Final">W</a>
#  </td>
#  <td><a href="/wiki/CONCACAF_Champions_League" title="CONCACAF Champions League">CONCACAF Champions League</a>
#  </td>
#  <td><a href="/wiki/2010%E2%80%9311_CONCACAF_Champions_League" title="2010–11 CONCACAF Champions League">GS</a>
#  </td>
#  <td>36,173
#  </td>
#  <td align="left"><span class="flagicon"><a href="/wiki/Colombia" title="Colombia"><img alt="Colombia" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/23px-Flag_of_Colombia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/35px-Flag_of_Colombia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/45px-Flag_of_Colombia.svg.png 2x" width="23"/></a></span> <a href="/wiki/Fredy_Montero" title="Fredy Montero">Fredy Montero</a>
#  </td>
#  <td>12
#  </td></tr>
#  <tr>
#  <td><b><a href="/wiki/2011_Seattle_Sounders_FC_season" title="2011 Seattle Sounders FC season">2011</a></b>
#  </td>
#  <td><a href="/wiki/2011_Major_League_Soccer_season" title="2011 Major League Soccer season">MLS</a>
#  </td>
#  <td>34
#  </td>
#  <td>18
#  </td>
#  <td>7
#  </td>
#  <td>9
#  </td>
#  <td>56
#  </td>
#  <td>37
#  </td>
#  <td>+19
#  </td>
#  <td>63
#  </td>
#  <td>1.85
#  </td>
#  <td bgcolor="silver">2nd
#  </td>
#  <td bgcolor="silver">2nd
#  </td>
#  <td><a href="/wiki/2011_MLS_Cup_Playoffs" title="2011 MLS Cup Playoffs">QF</a>
#  </td>
#  <td bgcolor="gold"><a href="/wiki/2011_U.S._Open_Cup_Final" title="2011 U.S. Open Cup Final">W</a>
#  </td>
#  <td><a href="/wiki/CONCACAF_Champions_League" title="CONCACAF Champions League">CONCACAF Champions League</a>
#  </td>
#  <td><a href="/wiki/2011%E2%80%9312_CONCACAF_Champions_League_Championship_Round#Quarterfinals" title="2011–12 CONCACAF Champions League Championship Round">QF</a>
#  </td>
#  <td>38,496
#  </td>
#  <td align="left"><span class="flagicon"><a href="/wiki/Colombia" title="Colombia"><img alt="Colombia" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/23px-Flag_of_Colombia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/35px-Flag_of_Colombia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/45px-Flag_of_Colombia.svg.png 2x" width="23"/></a></span> <a href="/wiki/Fredy_Montero" title="Fredy Montero">Fredy Montero</a>
#  </td>
#  <td>18
#  </td></tr>
#  <tr>
#  <td><b><a href="/wiki/2012_Seattle_Sounders_FC_season" title="2012 Seattle Sounders FC season">2012</a></b>
#  </td>
#  <td><a href="/wiki/2012_Major_League_Soccer_season" title="2012 Major League Soccer season">MLS</a>
#  </td>
#  <td>34
#  </td>
#  <td>15
#  </td>
#  <td>8
#  </td>
#  <td>11
#  </td>
#  <td>51
#  </td>
#  <td>33
#  </td>
#  <td>+18
#  </td>
#  <td>56
#  </td>
#  <td>1.65
#  </td>
#  <td bgcolor="CFAA88">3rd
#  </td>
#  <td>7th
#  </td>
#  <td><a href="/wiki/2012_MLS_Cup_Playoffs" title="2012 MLS Cup Playoffs">SF</a>
#  </td>
#  <td bgcolor="silver"><a href="/wiki/2012_U.S._Open_Cup_Final" title="2012 U.S. Open Cup Final">RU</a>
#  </td>
#  <td><a href="/wiki/CONCACAF_Champions_League" title="CONCACAF Champions League">CONCACAF Champions League</a>
#  </td>
#  <td><a href="/wiki/2012%E2%80%9313_CONCACAF_Champions_League#Semifinals" title="2012–13 CONCACAF Champions League">SF</a>
#  </td>
#  <td>43,144
#  </td>
#  <td align="left"><span class="flagicon"><a href="/wiki/United_States" title="United States"><img alt="United States" class="thumbborder" data-file-height="650" data-file-width="1235" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" width="23"/></a></span> <a href="/wiki/Eddie_Johnson_(American_soccer)" title="Eddie Johnson (American soccer)">Eddie Johnson</a><hr/><span class="flagicon"><a href="/wiki/Colombia" title="Colombia"><img alt="Colombia" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/23px-Flag_of_Colombia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/35px-Flag_of_Colombia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/45px-Flag_of_Colombia.svg.png 2x" width="23"/></a></span> <a href="/wiki/Fredy_Montero" title="Fredy Montero">Fredy Montero</a>
#  </td>
#  <td>17
#  </td></tr>
#  <tr>
#  <td><b><a href="/wiki/2013_Seattle_Sounders_FC_season" title="2013 Seattle Sounders FC season">2013</a></b>
#  </td>
#  <td><a href="/wiki/2013_Major_League_Soccer_season" title="2013 Major League Soccer season">MLS</a>
#  </td>
#  <td>34
#  </td>
#  <td>15
#  </td>
#  <td>12
#  </td>
#  <td>7
#  </td>
#  <td>42
#  </td>
#  <td>42
#  </td>
#  <td>0
#  </td>
#  <td>52
#  </td>
#  <td>1.53
#  </td>
#  <td>4th
#  </td>
#  <td>6th
#  </td>
#  <td><a href="/wiki/2013_MLS_Cup_Playoffs" title="2013 MLS Cup Playoffs">QF</a>
#  </td>
#  <td><a href="/wiki/2013_U.S._Open_Cup#Third_Round" title="2013 U.S. Open Cup">R3</a>
#  </td>
#  <td colspan="2" rowspan="2">DNQ
#  </td>
#  <td>44,038
#  </td>
#  <td align="left"><span class="flagicon"><a href="/wiki/United_States" title="United States"><img alt="United States" class="thumbborder" data-file-height="650" data-file-width="1235" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" width="23"/></a></span> <a href="/wiki/Eddie_Johnson_(American_soccer)" title="Eddie Johnson (American soccer)">Eddie Johnson</a>
#  </td>
#  <td>12
#  </td></tr>
#  <tr>
#  <td><b><a href="/wiki/2014_Seattle_Sounders_FC_season" title="2014 Seattle Sounders FC season">2014</a></b>
#  </td>
#  <td><a href="/wiki/2014_Major_League_Soccer_season" title="2014 Major League Soccer season">MLS</a>
#  </td>
#  <td>34
#  </td>
#  <td>20
#  </td>
#  <td>10
#  </td>
#  <td>4
#  </td>
#  <td>65
#  </td>
#  <td>50
#  </td>
#  <td>+15
#  </td>
#  <td>64
#  </td>
#  <td>1.88
#  </td>
#  <td bgcolor="gold">1st
#  </td>
#  <td bgcolor="gold">1st
#  </td>
#  <td><a href="/wiki/2014_MLS_Cup_Playoffs" title="2014 MLS Cup Playoffs">SF</a>
#  </td>
#  <td bgcolor="gold"><a href="/wiki/2014_U.S._Open_Cup_Final" title="2014 U.S. Open Cup Final">W</a>
#  </td>
#  <td>43,734
#  </td>
#  <td align="left"><span class="flagicon"><a href="/wiki/Nigeria" title="Nigeria"><img alt="Nigeria" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/23px-Flag_of_Nigeria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/35px-Flag_of_Nigeria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/46px-Flag_of_Nigeria.svg.png 2x" width="23"/></a></span> <a href="/wiki/Obafemi_Martins" title="Obafemi Martins">Obafemi Martins</a>
#  </td>
#  <td>19
#  </td></tr>
#  <tr>
#  <td><b><a href="/wiki/2015_Seattle_Sounders_FC_season" title="2015 Seattle Sounders FC season">2015</a></b>
#  </td>
#  <td><a href="/wiki/2015_Major_League_Soccer_season" title="2015 Major League Soccer season">MLS</a>
#  </td>
#  <td>34
#  </td>
#  <td>15
#  </td>
#  <td>13
#  </td>
#  <td>6
#  </td>
#  <td>44
#  </td>
#  <td>36
#  </td>
#  <td>+8
#  </td>
#  <td>51
#  </td>
#  <td>1.50
#  </td>
#  <td>4th
#  </td>
#  <td>6th
#  </td>
#  <td><a href="/wiki/2015_MLS_Cup_Playoffs" title="2015 MLS Cup Playoffs">QF</a>
#  </td>
#  <td><a href="/wiki/2015_U.S._Open_Cup#Fourth_Round" title="2015 U.S. Open Cup">R4</a>
#  </td>
#  <td><a href="/wiki/CONCACAF_Champions_League" title="CONCACAF Champions League">CONCACAF Champions League</a>
#  </td>
#  <td><a href="/wiki/2015%E2%80%9316_CONCACAF_Champions_League" title="2015–16 CONCACAF Champions League">QF</a>
#  </td>
#  <td style="background:#dfd;">44,245
#  </td>
#  <td align="left"><span class="flagicon"><a href="/wiki/Nigeria" title="Nigeria"><img alt="Nigeria" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/23px-Flag_of_Nigeria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/35px-Flag_of_Nigeria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/46px-Flag_of_Nigeria.svg.png 2x" width="23"/></a></span> <a href="/wiki/Obafemi_Martins" title="Obafemi Martins">Obafemi Martins</a>
#  </td>
#  <td>15
#  </td></tr>
#  <tr>
#  <td><b><a href="/wiki/2016_Seattle_Sounders_FC_season" title="2016 Seattle Sounders FC season">2016</a></b>
#  </td>
#  <td><a href="/wiki/2016_Major_League_Soccer_season" title="2016 Major League Soccer season">MLS</a>
#  </td>
#  <td>34
#  </td>
#  <td>14
#  </td>
#  <td>14
#  </td>
#  <td>6
#  </td>
#  <td>44
#  </td>
#  <td>43
#  </td>
#  <td>+1
#  </td>
#  <td>48
#  </td>
#  <td>1.41
#  </td>
#  <td>4th
#  </td>
#  <td>7th
#  </td>
#  <td bgcolor="gold"><a href="/wiki/MLS_Cup_2016" title="MLS Cup 2016">W</a>
#  </td>
#  <td><a href="/wiki/2016_U.S._Open_Cup#Quarterfinals" title="2016 U.S. Open Cup">QF</a>
#  </td>
#  <td colspan="2" rowspan="2">DNQ
#  </td>
#  <td>42,636
#  </td>
#  <td align="left"><span class="flagicon"><a href="/wiki/United_States" title="United States"><img alt="United States" class="thumbborder" data-file-height="650" data-file-width="1235" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" width="23"/></a></span> <a href="/wiki/Jordan_Morris" title="Jordan Morris">Jordan Morris</a>
#  </td>
#  <td>12
#  </td></tr>
#  <tr>
#  <td><b><a href="/wiki/2017_Seattle_Sounders_FC_season" title="2017 Seattle Sounders FC season">2017</a></b>
#  </td>
#  <td><a href="/wiki/2017_Major_League_Soccer_season" title="2017 Major League Soccer season">MLS</a>
#  </td>
#  <td>34
#  </td>
#  <td>14
#  </td>
#  <td>9
#  </td>
#  <td>11
#  </td>
#  <td>52
#  </td>
#  <td>39
#  </td>
#  <td>+13
#  </td>
#  <td>53
#  </td>
#  <td>1.56
#  </td>
#  <td bgcolor="silver">2nd
#  </td>
#  <td>7th
#  </td>
#  <td bgcolor="silver"><a href="/wiki/MLS_Cup_2017" title="MLS Cup 2017">RU</a>
#  </td>
#  <td><a href="/wiki/2017_U.S._Open_Cup#Round_of_16" title="2017 U.S. Open Cup">Ro16</a>
#  </td>
#  <td>43,666
#  </td>
#  <td align="left"><span class="flagicon"><a href="/wiki/United_States" title="United States"><img alt="United States" class="thumbborder" data-file-height="650" data-file-width="1235" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" width="23"/></a></span> <a href="/wiki/Clint_Dempsey" title="Clint Dempsey">Clint Dempsey</a>
#  </td>
#  <td>12
#  </td></tr>
#  <tr>
#  <td><b><a href="/wiki/2018_Seattle_Sounders_FC_season" title="2018 Seattle Sounders FC season">2018</a></b>
#  </td>
#  <td><a href="/wiki/2018_Major_League_Soccer_season" title="2018 Major League Soccer season">MLS</a>
#  </td>
#  <td>34
#  </td>
#  <td>18
#  </td>
#  <td>11
#  </td>
#  <td>5
#  </td>
#  <td>52
#  </td>
#  <td>37
#  </td>
#  <td>+15
#  </td>
#  <td>59
#  </td>
#  <td>1.74
#  </td>
#  <td bgcolor="silver">2nd
#  </td>
#  <td>4th
#  </td>
#  <td><a href="/wiki/2018_MLS_Cup_Playoffs" title="2018 MLS Cup Playoffs">QF</a>
#  </td>
#  <td><a href="/wiki/2018_U.S._Open_Cup#Fourth_round" title="2018 U.S. Open Cup">R4</a>
#  </td>
#  <td><a href="/wiki/CONCACAF_Champions_League" title="CONCACAF Champions League">CONCACAF Champions League</a>
#  </td>
#  <td><a href="/wiki/2018_CONCACAF_Champions_League" title="2018 CONCACAF Champions League">QF</a>
#  </td>
#  <td>40,641
#  </td>
#  <td align="left"><span class="flagicon"><a href="/wiki/Peru" title="Peru"><img alt="Peru" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Flag_of_Peru_%28state%29.svg/23px-Flag_of_Peru_%28state%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Flag_of_Peru_%28state%29.svg/35px-Flag_of_Peru_%28state%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/df/Flag_of_Peru_%28state%29.svg/45px-Flag_of_Peru_%28state%29.svg.png 2x" width="23"/></a></span> <a href="/wiki/Ra%C3%BAl_Ruid%C3%ADaz" title="Raúl Ruidíaz">Raúl Ruidíaz</a>
#  </td>
#  <td>13
#  </td></tr>
#  <tr>
#  <td><b><a href="/wiki/2019_Seattle_Sounders_FC_season" title="2019 Seattle Sounders FC season">2019</a></b>
#  </td>
#  <td><a href="/wiki/2019_Major_League_Soccer_season" title="2019 Major League Soccer season">MLS</a>
#  </td>
#  <td>34
#  </td>
#  <td>16
#  </td>
#  <td>10
#  </td>
#  <td>8
#  </td>
#  <td>52
#  </td>
#  <td>49
#  </td>
#  <td>+3
#  </td>
#  <td>56
#  </td>
#  <td>1.64
#  </td>
#  <td bgcolor="silver">2nd
#  </td>
#  <td>4th
#  </td>
#  <td bgcolor="gold"><a href="/wiki/MLS_Cup_2019" title="MLS Cup 2019">W</a>
#  </td>
#  <td><a href="/wiki/2019_U.S._Open_Cup#Fourth_Round" title="2019 U.S. Open Cup">R4</a>
#  </td>
#  <td colspan="2">DNQ
#  </td>
#  <td>40,247
#  </td>
#  <td align="left"><span class="flagicon"><a href="/wiki/Peru" title="Peru"><img alt="Peru" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Flag_of_Peru_%28state%29.svg/23px-Flag_of_Peru_%28state%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Flag_of_Peru_%28state%29.svg/35px-Flag_of_Peru_%28state%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/df/Flag_of_Peru_%28state%29.svg/45px-Flag_of_Peru_%28state%29.svg.png 2x" width="23"/></a></span> <a href="/wiki/Ra%C3%BAl_Ruid%C3%ADaz" title="Raúl Ruidíaz">Raúl Ruidíaz</a>
#  </td>
#  <td>15
#  </td></tr>
#  <tr>
#  <td><b><a href="/wiki/2020_Seattle_Sounders_FC_season" title="2020 Seattle Sounders FC season">2020</a></b>
#  </td>
#  <td><a href="/wiki/2020_Major_League_Soccer_season" title="2020 Major League Soccer season">MLS</a>
#  </td>
#  <td>22
#  </td>
#  <td>11
#  </td>
#  <td>5
#  </td>
#  <td>6
#  </td>
#  <td>44
#  </td>
#  <td>23
#  </td>
#  <td>+21
#  </td>
#  <td>39
#  </td>
#  <td>1.77
#  </td>
#  <td bgcolor="silver">2nd
#  </td>
#  <td>6th
#  </td>
#  <td bgcolor="silver"><a href="/wiki/MLS_Cup_2020" title="MLS Cup 2020">RU</a>
#  </td>
#  <td><a href="/wiki/2020_U.S._Open_Cup" title="2020 U.S. Open Cup">NH</a>
#  </td>
#  <td><a href="/wiki/CONCACAF_Champions_League" title="CONCACAF Champions League">CONCACAF Champions League</a> <hr/> <a href="/wiki/Campeones_Cup" title="Campeones Cup">Campeones Cup</a> <hr/><a href="/wiki/MLS_is_Back_Tournament" title="MLS is Back Tournament">MLS is Back Tournament</a>
#  </td>
#  <td><a href="/wiki/2020_CONCACAF_Champions_League" title="2020 CONCACAF Champions League">Ro16</a> <hr/> <a href="/wiki/2020_Campeones_Cup" title="2020 Campeones Cup">NH</a> <hr/><a href="/wiki/MLS_is_Back_Tournament" title="MLS is Back Tournament">Ro16</a>
#  </td>
#  <td>36,603
#  </td>
#  <td align="left"><span class="flagicon"><a href="/wiki/Peru" title="Peru"><img alt="Peru" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Flag_of_Peru_%28state%29.svg/23px-Flag_of_Peru_%28state%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Flag_of_Peru_%28state%29.svg/35px-Flag_of_Peru_%28state%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/df/Flag_of_Peru_%28state%29.svg/45px-Flag_of_Peru_%28state%29.svg.png 2x" width="23"/></a></span> <a href="/wiki/Ra%C3%BAl_Ruid%C3%ADaz" title="Raúl Ruidíaz">Raúl Ruidíaz</a>
#  </td>
#  <td>14
#  </td></tr>
#  <tr>
#  <td><b>Total</b>
#  </td>
#  <td>–
#  </td>
#  <td>–
#  </td>
#  <td><b>388</b>
#  </td>
#  <td><b>182</b>
#  </td>
#  <td><b>116</b>
#  </td>
#  <td><b>90</b>
#  </td>
#  <td><b>579</b>
#  </td>
#  <td><b>453</b>
#  </td>
#  <td><b>+126</b>
#  </td>
#  <td><b>636</b>
#  </td>
#  <td><b>1.64</b>
#  </td>
#  <td>–
#  </td>
#  <td>–
#  </td>
#  <td>–
#  </td>
#  <td>–
#  </td>
#  <td colspan="2">–
#  </td>
#  <td>–
#  </td>
#  <td align="left"><span class="flagicon"><a href="/wiki/Colombia" title="Colombia"><img alt="Colombia" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/23px-Flag_of_Colombia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/35px-Flag_of_Colombia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/45px-Flag_of_Colombia.svg.png 2x" width="23"/></a></span> <b><a href="/wiki/Fredy_Montero" title="Fredy Montero">Fredy Montero</a></b>
#  </td>
#  <td><b>60</b>
#  </td></tr></tbody></table>]

# %% [markdown]
# ## Prepare data

# %% [markdown]
# ### Seahawks

# %%
df_s = pd.read_html(str(table)) 
df_s = pd.DataFrame(df_s[1])
df_s = df_s.loc[:, df_s.columns.get_level_values(1).isin({"Team", "Pct"})]
df_s.columns = df_s.columns.droplevel()
df_s = df_s.iloc[:45].rename(columns={'Team':'year', 'Pct':'WL ratio Seahawks'})
df_s['year'] = df_s['year'].astype(int)

# %%
# 10-year moving average
df_s['WL ratio Seahawks Averaged'] = df_s.iloc[:,1].rolling(window=10).mean()
df_s = df_s[['year', 'WL ratio Seahawks Averaged']].dropna()
df_s.head()
# Out:
#     year  WL ratio Seahawks Averaged
# 9   1985                      0.4508
# 10  1986                      0.4990
# 11  1987                      0.5233
# 12  1988                      0.5233
# 13  1989                      0.5108

# %% [markdown]
# ### Mariners

# %%
df_m = pd.read_html(str(table_m)) 
df_m = pd.DataFrame(df_m[2])
df_m = df_m[['Teamseason','Win%']].iloc[:44].rename(columns={'Teamseason':'year', 'Win%':'WL ratio Mariners'})
df_m['year'] = df_m['year'].replace("\[.*\]", "", regex=True)
df_m['year'] = df_m['year'].astype(int)
df_m['WL ratio Mariners'] = df_m['WL ratio Mariners'].astype(float)

# %%
# 10-year moving average
df_m['WL ratio Mariners Averaged'] = df_m.iloc[:,1].rolling(window=10).mean()
df_m = df_m[['year', 'WL ratio Mariners Averaged']].dropna()
df_m.head()
# Out:
#     year  WL ratio Mariners Averaged
# 9   1986                      0.4094
# 10  1987                      0.4180
# 11  1988                      0.4252
# 12  1989                      0.4289
# 13  1990                      0.4400

# %% [markdown]
# ### Merge two datasets to df

# %%
df = pd.merge(df_s, df_m, how='inner', on=['year'])
df.set_index('year', inplace=True)
df.head()
# Out:
#       WL ratio Seahawks Averaged  WL ratio Mariners Averaged
# year
# 1986                      0.4990                      0.4094
# 1987                      0.5233                      0.4180
# 1988                      0.5233                      0.4252
# 1989                      0.5108                      0.4289
# 1990                      0.5421                      0.4400

# %% [markdown]
# ### Analyze, model, and visualize

# %%
ax = df.plot(figsize=(8,4));
ax.set_ylabel('Win Percentage');
# Out:
# <img src="data:image/png;base64,..." width="800">
